# %%
import requests

# %%
import json

# %%
import pandas as pd
import numpy as np

# %%
from functools import reduce

# %%
headers = {'User-Agent': 'Chrome 10', 'Cookie': 'device_id=24700f9f1986800ab4fcc880530dd0ed; s=d112i58nvv; xq_is_login=1; snbim_minify=true;'}
list_url = 'https://xueqiu.com/service/v5/stock/screener/quote/list?page=1&size=10&order=desc&orderby=percent&order_by=percent&market=CN&type=sh_sz'

# %%
indicate_url = 'https://stock.xueqiu.com/v5/stock/finance/cn/indicator.json?symbol=%s&type=%s&is_detail=true&count=%s'

# %%
res = requests.get(list_url, headers=headers)

# %%
stocks = json.loads(res.text)

# %%
stocks = stocks['data']['list']

# %%
stocks
# Out:
# [{'symbol': 'SZ300842',
#   'net_profit_cagr': 23.632729676737107,
#   'ps': 1.7961,
#   'type': 11,
#   'percent': 43.98,
#   'has_follow': False,
#   'tick_size': 0.01,
#   'pb_ttm': 2.9137,
#   'float_shares': 25000000,
#   'current': 22.98,
#   'amplitude': 13.35,
#   'pcf': None,
#   'current_year_percent': 43.98,
#   'float_market_capital': 574500000,
#   'market_capital': 2298000000,
#   'dividend_yield': None,
#   'lot_size': 100,
#   'roe_ttm': None,
#   'total_percent': 10.22,
#   'percent5m': 0,
#   'income_cagr': 10.04929176228908,
#   'amount': 939440.44,
#   'chg': 7.02,
#   'issue_date_ts': 1592409600000,
#   'main_net_inflows': 0,
#   'volume': 40928,
#   'volume_ratio': None,
#   'pb': 2.913,
#   'followers': 1023,
#   'turnover_rate': 0.16,
#   'first_percent': 43.98,
#   'name': 'N帝科',
#   'pe_ttm': 27.701,
#   'total_shares': 100000000},
#  {'symbol': 'SH605166',
#   'net_profit_cagr': 6.725785156340125,
#   'ps': 1.3642,
#   'type': 11,
#   'percent': 43.97,
# ...

# %%
list(map(lambda x:pd.Series(x), stocks))
# Out:
# [symbol                       SZ300842
#  net_profit_cagr               23.6327
#  ps                             1.7961
#  type                               11
#  percent                         43.98
#  has_follow                      False
#  tick_size                        0.01
#  pb_ttm                         2.9137
#  float_shares                 25000000
#  current                         22.98
#  amplitude                       13.35
#  pcf                              None
#  current_year_percent            43.98
#  float_market_capital        574500000
#  market_capital             2298000000
#  dividend_yield                   None
#  lot_size                          100
#  roe_ttm                          None
#  total_percent                   10.22
#  percent5m                           0
#  income_cagr                   10.0493
#  amount                         939440
#  chg                              7.02
#  issue_date_ts           1592409600000
# ...

# %%
pd.DataFrame(map(lambda x:pd.Series(x), stocks))
# Out:
#      symbol  net_profit_cagr         ps  type  percent  has_follow  tick_size  \
# 0  SZ300842        23.632730   1.796100    11    43.98       False       0.01
# 1  SH605166         6.725785   1.364200    11    43.97       False       0.01
# 2  SH688278       700.543579  36.082145    82    10.92       False       0.01
# 3  SH601005       -56.871002   0.664655    11    10.13       False       0.01
# 4  SZ000638        24.315736   8.094759    11    10.10       False       0.01
# 5  SZ002083       -12.609636   1.069206    11    10.10       False       0.01
# 6  SZ000030       -14.478168   1.128419    11    10.09       False       0.01
# 7  SZ300431              NaN   3.478679    11    10.06       False       0.01
# 8  SZ002903       -69.816745  24.872665    11    10.04       False       0.01
# 9  SZ300374       -38.995243   3.921769    11    10.04       False       0.01
#
#     pb_ttm  float_shares  current  ...  main_net_inflows     volume  \
# ...

# %%
url = indicate_url % ('SH688466', 'all', 20)

# %%
url
# Out:
# 'https://stock.xueqiu.com/v5/stock/finance/cn/indicator.json?symbol=SH688466&type=all&is_detail=true&count=20'

# %%
res.headers.__dict__
# Out:
# {'_store': OrderedDict([('date', ('Date', 'Thu, 18 Jun 2020 14:03:34 GMT')),
#               ('content-type',
#                ('Content-Type', 'application/json; charset=utf-8')),
#               ('transfer-encoding', ('Transfer-Encoding', 'chunked')),
#               ('connection', ('Connection', 'keep-alive')),
#               ('server', ('Server', 'openresty')),
#               ('vary', ('Vary', 'Accept-Encoding')),
#               ('x-powered-by', ('X-Powered-By', 'Express')),
#               ('set-cookie',
#                ('Set-Cookie',
# ...

# %%
res.cookies.__dict__
# Out:
# {'_policy': <http.cookiejar.DefaultCookiePolicy at 0x7f9976ddb4e0>,
#  '_cookies_lock': <unlocked _thread.RLock object owner=0 count=0 at 0x7f9976dbd1e0>,
#  '_cookies': {'.xueqiu.com': {'/': {'s': Cookie(version=0, name='s', value='cg130laanh', port=None, port_specified=False, domain='.xueqiu.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1624025014, discard=False, comment=None, comment_url=None, rest={'httpOnly': None}, rfc2109=False),
#     'xq_a_token': Cookie(version=0, name='xq_a_token', value='ea139be840cf88ff8c30e6943cf26aba8ad77358', port=None, port_specified=False, domain='.xueqiu.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'httpOnly': None}, rfc2109=False),
# ...

# %%
headers={'User-Agent': 'Chrome/78.0.3904.108',
        'Cookie': 'xqat=1d4a470d5de86f88e2294b6e498d02879f1c8248'}

# %%
resp = requests.get(url, headers=headers)

# %%
resp.text
# Out:
# '{"data":{"quote_name":"金科环境","currency_name":"人民币","org_type":1,"last_report_name":"2020一季报","statuses":null,"currency":"CNY","list":[{"report_date":1585584000000,"report_name":"2020一季报","ctime":1588774531000,"avg_roe":[1.03,null],"np_per_share":[4.4,null],"operate_cash_flow_ps":[-0.89,null],"basic_eps":[0.05,null],"capital_reserve":[0.98,null],"undistri_profit_ps":[2.2349,null],"net_interest_of_total_assets":[0.5084,null],"net_selling_rate":[6.2042,-0.40404399404447433],"gross_selling_rate":[31.0031,-0.47696867861758085],"total_revenue":[5.735765106E7,1.071626356848123],"operating_income_yoy":[107.1626,null],"net_profit_atsopc":[3798730.41,0.48337713446281816],"net_profit_atsopc_yoy":[48.3377,null],"net_profit_after_nrgal_atsolc":[3905700.0,null],"np_atsopc_nrgal_yoy":[59.932,null],"ore_dlt":[1.1199,null],"rop":[45.4419,null],"asset_liab_ratio":[47.3851,null],"current_ratio":[1.8336,null],"quick_ratio":[1.5472,null],"equity_multiplier":[1.9006,null],"equity_ratio":[0.9195,null],"ho
# ...

# %%
indicater = json.loads(resp.text)

# %%
indicater['data']['list']
# Out:
# [{'report_date': 1585584000000,
#   'report_name': '2020一季报',
#   'ctime': 1588774531000,
#   'avg_roe': [1.03, None],
#   'np_per_share': [4.4, None],
#   'operate_cash_flow_ps': [-0.89, None],
#   'basic_eps': [0.05, None],
#   'capital_reserve': [0.98, None],
#   'undistri_profit_ps': [2.2349, None],
#   'net_interest_of_total_assets': [0.5084, None],
#   'net_selling_rate': [6.2042, -0.40404399404447433],
#   'gross_selling_rate': [31.0031, -0.47696867861758085],
#   'total_revenue': [57357651.06, 1.071626356848123],
#   'operating_income_yoy': [107.1626, None],
#   'net_profit_atsopc': [3798730.41, 0.48337713446281816],
#   'net_profit_atsopc_yoy': [48.3377, None],
#   'net_profit_after_nrgal_atsolc': [3905700.0, None],
#   'np_atsopc_nrgal_yoy': [59.932, None],
#   'ore_dlt': [1.1199, None],
#   'rop': [45.4419, None],
#   'asset_liab_ratio': [47.3851, None],
#   'current_ratio': [1.8336, None],
#   'quick_ratio': [1.5472, None],
#   'equity_multiplier': [1.9006, None],
# ...

# %%
df = pd.DataFrame(map(lambda x:pd.Series(x), indicater['data']['list']))

# %%
df[df.report_name.str.contains(r'.*年报')].T
# Out:
#                                                                  1  \
# report_date                                          1577721600000
# report_name                                                 2019年报
# ctime                                                1585756821000
# avg_roe                               [25.07, -0.1578770574403762]
# np_per_share                           [4.35, 0.28698224852070997]
# operate_cash_flow_ps                    [1.17, 0.4268292682926829]
# basic_eps                              [0.97, 0.11494252873563215]
# capital_reserve                                        [0.98, 0.0]
# undistri_profit_ps                    [2.1857, 0.6963135428793172]
# net_interest_of_total_assets        [11.7526, -0.1822344067466393]
# net_selling_rate                   [15.2386, -0.08212263582700882]
# gross_selling_rate                   [34.02, -0.05318790685506421]
# total_revenue                   [504557542.63, 0.2546614174028732]
# ...

# %%
tf = df.T

# %%
df
# Out:
#      report_date report_name          ctime                       avg_roe  \
# 0  1585584000000     2020一季报  1588774531000                  [1.03, None]
# 1  1577721600000      2019年报  1585756821000  [25.07, -0.1578770574403762]
# 2  1569772800000     2019三季报  1576520698000                  [None, None]
# 3  1561824000000      2019中报  1576520701000                  [9.67, None]
# 4  1553961600000     2019一季报  1588773991000                  [None, None]
# 5  1546185600000      2018年报  1576520710000  [29.77, 0.24612808706571782]
# 6  1538236800000     2018三季报  1576520713000                  [None, None]
# 7  1514649600000      2017年报  1576520719000   [23.89, 0.5789821546596167]
# 8  1483113600000      2016年报  1576520722000                 [15.13, None]
#
#                    np_per_share        operate_cash_flow_ps  \
# 0                   [4.4, None]               [-0.89, None]
# 1   [4.35, 0.28698224852070997]  [1.17, 0.4268292682926829]
# ...
